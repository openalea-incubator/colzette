# %% [markdown]
# # OpenAlea Colzette Gallery
# You will find below links to different Jupyter tutorial notebooks.

# %% [markdown]
# ## Light interception calculation
# This a simulation workflow example to calculate the surfacic density of energy absorbed Eabs (m-2) or the surfacic density of energy incoming Ei (m-2).
#
# - [Monocrop](monocrop_calculation.ipynb)
# - [Intercrop](intercrop_calculation.ipynb)
